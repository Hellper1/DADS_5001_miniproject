# %%
import pandas as pd
import numpy as np

# %%
pd.__version__
# Out:
# '1.4.2'

# %%
#Import file

df_production = pd.read_csv('https://raw.githubusercontent.com/Hellper1/DADS_5001_miniproject/main/dataset/electricity-production-by-source.csv')
df_consumption = pd.read_csv('https://raw.githubusercontent.com/Hellper1/DADS_5001_miniproject/main/dataset/energy-consumption-by-source-and-country.csv')
df_co2 = pd.read_csv('https://raw.githubusercontent.com/Hellper1/DADS_5001_miniproject/main/dataset/annual-co2-emissions-per-country.csv')
df_temp = pd.read_csv('https://raw.githubusercontent.com/Hellper1/DADS_5001_miniproject/main/dataset/FAOSTAT_data_en_2-12-2023.csv')

# %%
#Merge file

df = df_production.merge(df_consumption, how='right',on=['Entity','Code','Year']).merge(df_co2, how='left', on=['Entity','Code','Year']).merge(df_temp, how='left', on=['Entity','Code','Year'])

# %%
df.to_csv('miniproject.csv')

# %%
df
# Out:
#       Entity      Code  Year  Electricity from coal (TWh)  \
# 0     Africa       NaN  1965                          NaN
# 1     Africa       NaN  1966                          NaN
# 2     Africa       NaN  1967                          NaN
# 3     Africa       NaN  1968                          NaN
# 4     Africa       NaN  1969                          NaN
# ...      ...       ...   ...                          ...
# 5977   World  OWID_WRL  2017                      9521.49
# 5978   World  OWID_WRL  2018                      9903.24
# 5979   World  OWID_WRL  2019                      9684.76
# 5980   World  OWID_WRL  2020                      9294.85
# 5981   World  OWID_WRL  2021                     10110.98
#
#       Electricity from gas (TWh)  Electricity from nuclear (TWh)  \
# 0                            NaN                             NaN
# 1                            NaN                             NaN
# 2                            NaN                             NaN
# 3                            NaN                             NaN
# 4                            NaN                             NaN
# ...                          ...                             ...
# 5977                     5832.14                         2565.63
# 5978                     6046.61                         2618.98
# 5979                     6230.48                         2723.54
# 5980                     6151.05                         2634.15
# 5981                     6317.60                         2738.44
#
#       Electricity from hydro (TWh)  Electricity from solar (TWh)  \
# 0                              NaN                           NaN
# 1                              NaN                           NaN
# 2                              NaN                           NaN
# 3                              NaN                           NaN
# 4                              NaN                           NaN
# ...                            ...                           ...
# 5977                       4050.18                        444.54
# 5978                       4179.20                        570.66
# 5979                       4202.08                        700.72
# 5980                       4331.88                        849.67
# 5981                       4226.34                       1021.22
#
#       Electricity from oil (TWh)  Electricity from wind (TWh)  ...  \
# 0                            NaN                          NaN  ...
# 1                            NaN                          NaN  ...
# 2                            NaN                          NaN  ...
# 3                            NaN                          NaN  ...
# 4                            NaN                          NaN  ...
# ...                          ...                          ...  ...
# 5977                      872.56                      1136.40  ...
# 5978                      798.23                      1265.06  ...
# 5979                      740.93                      1419.43  ...
# 5980                      710.63                      1586.20  ...
# 5981                      760.15                      1848.26  ...
#
#       Biofuels Consumption - TWh - Total (zero filled)  \
# 0                                               0.0000
# 1                                               0.0000
# 2                                               0.0000
# 3                                               0.0000
# 4                                               0.0000
# ...                                                ...
# 5977                                          972.5343
# 5978                                         1045.9080
# 5979                                         1120.1494
# 5980                                         1065.5650
# 5981                                         1139.9211
#
#       Solar Consumption - TWh (zero filled)  \
# 0                                    0.0000
# 1                                    0.0000
# 2                                    0.0000
# 3                                    0.0000
# 4                                    0.0000
# ...                                     ...
# 5977                              1185.5151
# 5978                              1524.5498
# 5979                              1855.5922
# 5980                              2222.4430
# 5981                              2701.7222
#
#       Wind Consumption - TWh (zero filled)  \
# 0                                   0.0000
# 1                                   0.0000
# 2                                   0.0000
# 3                                   0.0000
# 4                                   0.0000
# ...                                    ...
# 5977                             3034.9170
# 5978                             3360.0188
# 5979                             3744.5151
# 5980                             4192.6820
# 5981                             4872.0950
#
#       Hydro Consumption - TWh (zero filled)  \
# 0                                 41.118813
# 1                                 45.862915
# 2                                 47.875538
# 3                                 56.000473
# 4                                 65.352100
# ...                                     ...
# 5977                           10831.405000
# 5978                           11067.518000
# 5979                           11153.792000
# 5980                           11413.828000
# 5981                           11183.226000
#
#       Nuclear Consumption - TWh (zero filled)  \
# 0                                      0.0000
# 1                                      0.0000
# 2                                      0.0000
# 3                                      0.0000
# 4                                      0.0000
# ...                                       ...
# 5977                                6734.8735
# 5978                                6856.0166
# 5979                                7073.2896
# 5980                                6789.3020
# 5981                                7031.3400
#
#       Gas Consumption - TWh (zero filled)  \
# 0                                9.543755
# 1                               10.669916
# 2                               10.545670
# 3                               10.688970
# 4                               12.492000
# ...                                   ...
# 5977                         36529.223000
# 5978                         38356.300000
# 5979                         39062.945000
# 5980                         38455.727000
# 5981                         40374.605000
#
#       Coal Consumption - TWh (zero filled)  \
# 0                                323.49612
# 1                                323.12220
# 2                                330.29156
# 3                                343.51290
# 4                                346.64294
# ...                                    ...
# 5977                           43751.67600
# 5978                           44315.87500
# 5979                           43699.88700
# 5980                           41963.96500
# 5981                           44473.19500
#
#       Oil Consumption - TWh (zero filled)  Annual CO2 emissions  Value
# 0                               341.26276          2.137846e+08    NaN
# 1                               369.48657          2.212616e+08    NaN
# 2                               368.12524          2.372577e+08    NaN
# 3                               389.19986          2.576002e+08    NaN
# 4                               396.92285          2.781395e+08    NaN
# ...                                   ...                   ...    ...
# 5977                          52515.54300          3.609674e+10    NaN
# 5978                          53250.62000          3.682651e+10    NaN
# 5979                          53368.63000          3.708256e+10    NaN
# 5980                          48380.71000          3.526409e+10    NaN
# 5981                          51170.47300          3.712385e+10    NaN
#
# [5982 rows x 23 columns]
